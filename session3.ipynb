# %% [markdown]
# # Session3

# %% [markdown]
# Task1
#
#
# Declare four variables in Python: one integer (number of followers), one float (average rating), one string (your favorite app's name), and one boolean (is_premium_user). Print each variable and its type using the type() function.

# %%
followers = 1500            # Integer
average_rating = 4.8        # Float
favorite_app = "Instagram"  # String
is_premium_user = True      # Boolean

print(followers)
print(type(followers))

print(average_rating)
print(type(average_rating))

print(favorite_app)
print(type(favorite_app))

print(is_premium_user)
print(type(is_premium_user))
# Out:
# 1500
# <class 'int'>
# 4.8
# <class 'float'>
# Instagram
# <class 'str'>
# True
# <class 'bool'>

# %% [markdown]
# Task2
#
# Write a Python program that takes a user's input for the price of a Zomato order as a string, converts it to a float using type casting, adds 18% GST, and prints the final bill amount.

# %%
order_price = input("Enter Zomato order price: ")


order_price = float(order_price)


gst = order_price * 0.18

final_bill = order_price + gst

print("Final bill amount:", final_bill)
# Out:
# Final bill amount: 236.0

# %% [markdown]
# Task3
#
#
# Given a list of strings representing product prices from Flipkart, like ['199.99', '299.50', '150'], convert all to floats and calculate the total cart value.

# %%
price=['199.99', '299.50', '150']
price1=float(price[0])
price2=float(price[1])
price3=float(price[2])
print(type(price1))
print(type(price2))
print(type(price3))

total=price1+price2+price3
print(total)
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# 649.49

# %% [markdown]
# Task4
#
# Build a function is_discount_applicable(order_amount) that takes a float and returns True if the amount is greater than 500, otherwise False. Print the result for order amounts 450 and 750.

# %%
def is_discount_applicable(order_amount):
    
    if(order_amount>500):
        return True
    else:
        return False

print(is_discount_applicable(450))
print(is_discount_applicable(750))
# Out:
# False
# True

# %% [markdown]
# Task5
#
# You received a dataset of ratings as strings from Spotify: ['4.5', '3.0', '5', '4.2']. Use type casting to convert these to floats, then find and print the highest rating.<br><br><em><strong>Hint:</strong> Use the float() function inside a loop or list comprehension.</em>

# %%
Spotify = ['10', '3.0', '5', '4.2']
Spotify1=float(Spotify[0])
Spotify2=float(Spotify[1])
Spotify3=float(Spotify[2])
Spotify4=float(Spotify[3])
print(type(Spotify1))
print(type(Spotify2))
print(type(Spotify3))
print(type(Spotify4))
max(Spotify1,Spotify2,Spotify3,Spotify4)
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# 10.0
