# %% [markdown]
# # Session17

# %% [markdown]
# #Task1
#
# Use the math module to calculate the square root, factorial, and value of pi for given numbers, and print each result.

# %%
import math
print(math.sqrt(2))
print(math.factorial(5))
print(math.pi)
# Out:
# 1.4142135623730951
# 120
# 3.141592653589793

# %% [markdown]
# #Task2
#
#
# Write a script that lists all files in your current directory using the os module, and prints only those files with a .jpg or .png extension.<br><br><em><strong>Hint:</strong> Use os.listdir() and string methods to filter file names.</em>

# %%
import os

files = os.listdir()
print(files)
print("Image Files:")

for file in files:
    if file.endswith(".jpg") or file.endswith(".png"):
        print(file)
else:
        print("There is no jpg or png file found...")
# Out:
# ['50_questions.ipynb', 'abc.txt', 'abstraction.ipynb', 'advance_datatype.ipynb', 'BM.txt', 'condition.ipynb', 'data.txt', 'data2.csv', 'data2.txt', 'data3.txt', 'demo.py', 'demo1.py', 'demo2.py', 'dictionary_datatype.ipynb', 'encapsulation.ipynb', 'exam.ipynb', 'exception_handling.ipynb', 'file_handling.ipynb', 'file_handling1.ipynb', 'forloop.ipynb', 'function.ipynb', 'high_function.ipynb', 'inheritense.ipynb', 'ipl_scores.csv', 'iter.ipynb', 'list_datatype.ipynb', 'loop.ipynb', 'man.json', 'man.txt', 'man1.csv', 'man1.txt', 'mansi', 'mansi.txt', 'module.ipynb', 'MyFolder', 'myplaylist.txt', 'oops.ipynb', 'p1.ipynb', 'p2.ipynb', 'p3.ipynb', 'pattern.ipynb', 'polimorphism.ipynb', 'practical.ipynb', 'practical2.ipynb', 'practise_work _for_python.ipynb', 'recursion.ipynb', 'score.txt', 'Session1.ipynb', 'session12.ipynb', 'session13.ipynb', 'session14.ipynb', 'Session15.ipynb', 'session16.ipynb', 'session17.ipynb', 'session2.ipynb', 'session3.ipynb', 'session4.ipynb', 'session5.ipynb', 'session6.ipynb', 'session7.ipynb', 'session8.ipynb', 'session9.ipynb', 'set_datatype.ipynb', 'student.txt', 'student1.txt', 'student_data1.txt', 'student_data2.txt', 'tuple_datatype.ipynb', 'user_profile', 'user_profile.json', 'user_profile.txt', '__pycache__']
# Image Files:
# There is no jpg or png file found...

# %% [markdown]
# #Task3
#
# Create a Python program that accepts a date in 'YYYY-MM-DD' format from the user and displays the day of the week using the datetime module.

# %%
from datetime import datetime

# User input
date = input("Enter a date (YYYY-MM-DD): ")

# Convert string to date
d = datetime.strptime(date, "%Y-%m-%d")

# Display the day of the week
print("Day of the week:", d.strftime("%A"))
# Out:
# Day of the week: Saturday

# %% [markdown]
# #Task4
#
# Build a simple custom module named insta_utils.py with a function format_follower_count(n) that returns '1.5K' for 1500 and '2.3M' for 2300000. Import and use this function in another script to display formatted counts for 3 sample numbers.

# %%
from insta_utils import format_follower_count
n=int(input("Enter Your follwer "))
print(format_follower_count(n))
# Out:
# 1.5K

# %% [markdown]
# #Task5
#
#
# Create a new virtual environment using venv, activate it, and install the statistics and requests packages via pip. Then, write a script that uses statistics.mean() to calculate the average of a list of numbers.

# %%
# Step 1: python -m venv myenv
# Step 2: myenv\Scripts\activate
# Step 3:pip install requests

import statistics

numbers = [10, 20, 30, 40, 50]

average = statistics.mean(numbers)

print("Average =", average)
# Out:
# Average = 30
